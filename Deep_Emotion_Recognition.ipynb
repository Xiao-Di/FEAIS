# %% [markdown]
# <a href="https://colab.research.google.com/github/skanelo/Deep-Emotion-Recognition/blob/main/Deep_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Emotion Recognition system that bases its predictions on facial expressions

# %% [markdown]
# ### Import the necessary libraries

# %%
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sn
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# from google.colab import drive
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dropout, Dense, Input, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical, plot_model

# %%
plt.rc('font',family='Times New Roman')

# %%
# some colors
r_hex= '#dc2624'# red, RGB = 220,38,36 
dt_hex= '#2b4750'# dark teal, RGB = 43,71,80 
tl_hex= '#45a0a2'# teal, RGB = 69,160,162 
r1_hex= '#e87a59'# red, RGB = 232,122,89 
tl1_hex= '#7dcaa9'# teal, RGB = 125,202,169 
g_hex= '#649E7D'# green, RGB = 100,158,125 
o_hex= '#dc8018'# orange, RGB = 220,128,24 
tn_hex= '#C89F91'# tan, RGB = 200,159,145 
g50_hex= '#6c6d6c'# grey-50, RGB = 108,109,108 
bg_hex= '#4f6268'# blue grey, RGB = 79,98,104 
g25_hex= '#c7cccf'# grey-25, RGB = 199,204,207

# %% [markdown]
# ### Load and preprocess the data

# %%
# Auxiliary function for data distribution visualization
def data_visualization(classes, data, mode='Train'):
    """
    Vizualize the distribution of the dataset.
  
    This function presents the number of samples each category has
    through a bar plot.

    Args:
        classes (list): List of the emotion-categories
        data (list): List of the number of images per category 
 
    Returns:
        No value
    """

    # fig, ax = plt.subplots(figsize=(9, 5))
    fig, ax = plt.subplots(figsize=(9, 7))
    # ax.bar(classes, data, color=dt_hex)
    ax.bar(classes, data, color=tl_hex)
    ax.set(title=f"{mode} dataset's distribution for each Emotion class")
    ax.set(xlabel="Emotions", ylabel="Number of Images")
    ax.grid()
    plt.savefig(f'/Users/gengyunxin/Documents/研究生/ICALT/result/{mode}_data_distribution.eps', format='eps', dpi=1000)
    plt.savefig(f'/Users/gengyunxin/Documents/研究生/ICALT/result/{mode}_data_distribution.png')
    # plt.show()


def load_data(data_path, mode='Train'):
    """
    Load the dataset to the memory.

    This function takes a data path and loads all images (along with their
    corresponding labels) as numpy arrays per category to the memory.
    Subsequently, the labels are one-hot encoded. Before the images, labels
    are returned, the distribution of the dataset is presented.

    Args:
        data_path (str): The path of the dataset's whereabouts

    Returns:
        data (numpy.ndarray): The images of the dataset
        labels (numpy.ndarray): The labels of each image
    """

    subfolders_ck = os.listdir(data_path)

    print("[INFO] Dataset Loading...\n")

    img_data_list=[]
    labels_list = []
    num_images_per_class = []

    for category in subfolders_ck:
        img_list=os.listdir(data_path +'/'+ category)
        
        print('Loading :', len(img_list), 'images of category', category)
        for img in img_list:
            # Load an image from this path
            pixels=cv2.imread(data_path + '/'+ category + '/'+ img )
            face_array=cv2.resize(pixels, None, fx=1, fy=1,interpolation = cv2.INTER_CUBIC)
        
            img_data_list.append(face_array)          
            labels_list.append(category)

        num_images_per_class.append(len(img_list))

    # print(labels_list)
    data = np.array(img_data_list)
    le = LabelEncoder()
    labels = le.fit_transform(labels_list)
    # labels = to_categorical(labels, 6)
    labels = to_categorical(labels, 8)
    # print(labels[0])    # happy     4
    # print(labels[900])  # contempt  1
    # print(labels[950])  # fear      3
    # print(labels[1250]) # surprise  7
    # print(labels[1770]) # sadness   6
    # print(labels[2800]) # neutrual  5
    # print(labels[3000]) # anger     0
    # print(labels[3150]) # disgust   2

    data_visualization(subfolders_ck, num_images_per_class, mode=mode)

    # Dataset Summary
    print("\nTotal number of uploaded data: ", data.shape[0],
          ", with data shape", (data.shape[1],data.shape[2],data.shape[3]))

    return data, labels

# %%
# data_path_ck = "/Users/gengyunxin/Documents/研究生/ICALT/DO/Deep-Emotion-Recognition-main/CK+48"
# data, labels = load_data(data_path_ck)
data_path_fer_train = '/Users/gengyunxin/Documents/研究生/ICALT/dataset/fer2013_plus/Training'
X_train, y_train = load_data(data_path_fer_train, mode='Train')
# Out:
# [INFO] Dataset Loading...
#
# Loading : 7287 images of category Happy
# Loading : 119 images of category Contempt
# Loading : 532 images of category Fear
# Loading : 3149 images of category Surprise
# Loading : 3014 images of category Sadness
# Loading : 8740 images of category Neutral
# Loading : 2100 images of category Anger
# Loading : 119 images of category Disgust
#
# Total number of uploaded data:  25060 , with data shape (48, 48, 3)

# %%
data_path_fer_valid = '/Users/gengyunxin/Documents/研究生/ICALT/dataset/fer2013_plus/PublicTest'
X_valid, y_valid = load_data(data_path_fer_valid, mode='Valid')
# Out:
# [INFO] Dataset Loading...
#
# Loading : 865 images of category Happy
# Loading : 13 images of category Contempt
# Loading : 62 images of category Fear
# Loading : 415 images of category Surprise
# Loading : 351 images of category Sadness
# Loading : 1182 images of category Neutral
# Loading : 287 images of category Anger
# Loading : 24 images of category Disgust
#
# Total number of uploaded data:  3199 , with data shape (48, 48, 3)

# %%
data_path_fer_test = '/Users/gengyunxin/Documents/研究生/ICALT/dataset/fer2013_plus/PrivateTest'
X_test, y_test = load_data(data_path_fer_test, mode='Test')
# Out:
# [INFO] Dataset Loading...
#
# Loading : 893 images of category Happy
# Loading : 16 images of category Contempt
# Loading : 83 images of category Fear
# Loading : 396 images of category Surprise
# Loading : 384 images of category Sadness
# Loading : 1090 images of category Neutral
# Loading : 273 images of category Anger
# Loading : 18 images of category Disgust
#
# Total number of uploaded data:  3153 , with data shape (48, 48, 3)

# %%
# Split the dataset into two subsets (70%-30%). The first one will be used for training.
# X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, shuffle=True, random_state=3)
print(f"X_train has shape: {X_train.shape}")
print(f"y_train has shape: {y_train.shape}\n")
# The second subset will be split into validation and test set (50%-50%).
# X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5, shuffle=True, random_state=3)
print(f"X_valid has shape: {X_valid.shape}")
print(f"y_valid has shape: {y_valid.shape}\n")
print(f"X_test has shape: {X_test.shape}")
print(f"y_test has shape: {y_test.shape}\n")
print(f"X_train + X_valid + X_test = {X_train.shape[0] + X_valid.shape[0] + X_test.shape[0]} samples in total")
# Out:
# X_train has shape: (25060, 48, 48, 3)
# y_train has shape: (25060, 8)
#
# X_valid has shape: (3199, 48, 48, 3)
# y_valid has shape: (3199, 8)
#
# X_test has shape: (3153, 48, 48, 3)
# y_test has shape: (3153, 8)
#
# X_train + X_valid + X_test = 31412 samples in total

# %%
# Map the emotion-categories
# mapping = {0:'anger', 1:'disgust', 2:'fear', 3:'happy', 4:'sad', 5:'surprised', 6:'normal'}
mapping = {0:'anger', 1:'contempt', 2:'disgust', 3:'fear', 4:'happy', 5:'neutral', 6:'sadness', 7:'surprise'}

# Initialize the training data augmentation object
trainAug = ImageDataGenerator(rotation_range=15,
                              zoom_range=0.15,
                              #width_shift_range=0.2,
                              brightness_range=(.6, 1.2),
                              shear_range=.15,
                              #height_shift_range=0.2,
                              horizontal_flip=True,
                              fill_mode="nearest")

# Randomly vizualize some augmented samples
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(trainAug.flow(X_train, y_train, batch_size=1)):
    if i == 9:
        break
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(image)/255.)
    plt.title(mapping[np.argmax(label)])
    plt.axis("off")
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/sample_plot.eps', format='eps', dpi=1000)
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/sample_plot.png')
# plt.show()

# %% [markdown]
# ### Create the model

# %%
def build_model():
    """
    Create the new model.
  
    This function loads a pre-trained EfficientNetB0 model on Imagenet,
    adds an Input layer at the beggining, and 3 more layers at the end
    (i.e GlobalAveragePooling2D, Dropout, Dense).

    Args:
        No value
   
    Returns:
        model (tensorflow.python.keras.engine.functional.Functional): The compiled model
    """
    
    inputs = Input(shape=(48, 48, 3))
    base_model = EfficientNetB0(include_top=False, weights='imagenet',
                                drop_connect_rate=0.33, input_tensor=inputs)
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(.1, name="top_dropout")(x)
    # outputs = Dense(6, activation='softmax')(x)
    outputs = Dense(8, activation='softmax')(x)
    model = Model(inputs, outputs)
    
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Create an object of the model
model = build_model()

# %% [markdown]
# ### Save the summary and the plot of the model into files

# %%
from contextlib import redirect_stdout

with open('modelsummary.txt', 'w') as f:
    with redirect_stdout(f):
        model.summary()

#print(model.summary())
# plot_model(model, to_file='model.png')

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 100
batch_size = 32
filepath = "/Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5"

# Define the necessary callbacks
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
earlystopping = EarlyStopping(monitor='val_accuracy', patience=15, verbose=1, mode='auto', restore_best_weights=True)
rlrop = ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-6, verbose=1)

callbacks = [checkpoint, earlystopping, rlrop]

print(f"[INFO] training network for {EPOCHS} epochs...\n")
hist = model.fit(trainAug.flow(X_train, y_train, batch_size=batch_size),
                 steps_per_epoch=len(X_train) // batch_size,
                 validation_data=(X_valid, y_valid),
                 epochs=EPOCHS, callbacks=callbacks)
# Out:
# [INFO] training network for 100 epochs...
#
# Epoch 1/100
# 783/783 [==============================] - ETA: 0s - loss: 1.1187 - accuracy: 0.5973
# Epoch 00001: val_accuracy improved from -inf to 0.66364, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 236s 301ms/step - loss: 1.1187 - accuracy: 0.5973 - val_loss: 0.9426 - val_accuracy: 0.6636
# Epoch 2/100
# 783/783 [==============================] - ETA: 0s - loss: 0.9564 - accuracy: 0.6586
# Epoch 00002: val_accuracy improved from 0.66364 to 0.70553, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 241s 308ms/step - loss: 0.9564 - accuracy: 0.6586 - val_loss: 0.8408 - val_accuracy: 0.7055
# Epoch 3/100
# 783/783 [==============================] - ETA: 0s - loss: 0.8508 - accuracy: 0.6971
# Epoch 00003: val_accuracy improved from 0.70553 to 0.72085, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 226s 288ms/step - loss: 0.8508 - accuracy: 0.6971 - val_loss: 0.7875 - val_accuracy: 0.7209
# Epoch 4/100
# 783/783 [==============================] - ETA: 0s - loss: 0.7791 - accuracy: 0.7207
# Epoch 00004: val_accuracy improved from 0.72085 to 0.74242, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 222s 283ms/step - loss: 0.7791 - accuracy: 0.7207 - val_loss: 0.7181 - val_accuracy: 0.7424
# Epoch 5/100
# 783/783 [==============================] - ETA: 0s - loss: 0.7272 - accuracy: 0.7377
# Epoch 00005: val_accuracy improved from 0.74242 to 0.76274, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 212s 271ms/step - loss: 0.7272 - accuracy: 0.7377 - val_loss: 0.6747 - val_accuracy: 0.7627
# Epoch 6/100
# 783/783 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.7554
# Epoch 00006: val_accuracy did not improve from 0.76274
# 783/783 [==============================] - 283s 361ms/step - loss: 0.6828 - accuracy: 0.7554 - val_loss: 0.6689 - val_accuracy: 0.7590
# Epoch 7/100
# 783/783 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.7660
# Epoch 00007: val_accuracy improved from 0.76274 to 0.77743, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 277s 354ms/step - loss: 0.6422 - accuracy: 0.7660 - val_loss: 0.6392 - val_accuracy: 0.7774
# Epoch 8/100
# 783/783 [==============================] - ETA: 0s - loss: 0.6072 - accuracy: 0.7815
# Epoch 00008: val_accuracy improved from 0.77743 to 0.78868, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 320s 408ms/step - loss: 0.6072 - accuracy: 0.7815 - val_loss: 0.6180 - val_accuracy: 0.7887
# Epoch 9/100
# 783/783 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.7869
# Epoch 00009: val_accuracy did not improve from 0.78868
# 783/783 [==============================] - 237s 303ms/step - loss: 0.5823 - accuracy: 0.7869 - val_loss: 0.6161 - val_accuracy: 0.7859
# Epoch 10/100
# 783/783 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.8034
# Epoch 00010: val_accuracy improved from 0.78868 to 0.79337, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 221s 282ms/step - loss: 0.5497 - accuracy: 0.8034 - val_loss: 0.5927 - val_accuracy: 0.7934
# Epoch 11/100
# 783/783 [==============================] - ETA: 0s - loss: 0.5243 - accuracy: 0.8081
# Epoch 00011: val_accuracy did not improve from 0.79337
# 783/783 [==============================] - 216s 275ms/step - loss: 0.5243 - accuracy: 0.8081 - val_loss: 0.6066 - val_accuracy: 0.7896
# Epoch 12/100
# 783/783 [==============================] - ETA: 0s - loss: 0.5042 - accuracy: 0.8154
# Epoch 00012: val_accuracy improved from 0.79337 to 0.79462, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 245s 312ms/step - loss: 0.5042 - accuracy: 0.8154 - val_loss: 0.5987 - val_accuracy: 0.7946
# Epoch 13/100
# 783/783 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.8226
# Epoch 00013: val_accuracy improved from 0.79462 to 0.79681, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 239s 305ms/step - loss: 0.4808 - accuracy: 0.8226 - val_loss: 0.5832 - val_accuracy: 0.7968
# Epoch 14/100
# 783/783 [==============================] - ETA: 0s - loss: 0.4588 - accuracy: 0.8345
# Epoch 00014: val_accuracy improved from 0.79681 to 0.80588, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 218s 278ms/step - loss: 0.4588 - accuracy: 0.8345 - val_loss: 0.5677 - val_accuracy: 0.8059
# Epoch 15/100
# 783/783 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.8397
# Epoch 00015: val_accuracy did not improve from 0.80588
# 783/783 [==============================] - 230s 294ms/step - loss: 0.4423 - accuracy: 0.8397 - val_loss: 0.5883 - val_accuracy: 0.7987
# Epoch 16/100
# 783/783 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8456
# Epoch 00016: val_accuracy did not improve from 0.80588
# 783/783 [==============================] - 212s 270ms/step - loss: 0.4209 - accuracy: 0.8456 - val_loss: 0.5891 - val_accuracy: 0.7974
# Epoch 17/100
# 783/783 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8512
# Epoch 00017: val_accuracy did not improve from 0.80588
# 783/783 [==============================] - 212s 270ms/step - loss: 0.4099 - accuracy: 0.8512 - val_loss: 0.5883 - val_accuracy: 0.8059
# Epoch 18/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8556
# Epoch 00018: val_accuracy did not improve from 0.80588
# 783/783 [==============================] - 209s 267ms/step - loss: 0.3954 - accuracy: 0.8556 - val_loss: 0.5924 - val_accuracy: 0.7990
# Epoch 19/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8640
# Epoch 00019: val_accuracy did not improve from 0.80588
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 783/783 [==============================] - 206s 264ms/step - loss: 0.3686 - accuracy: 0.8640 - val_loss: 0.5902 - val_accuracy: 0.8012
# Epoch 20/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.8742
# Epoch 00020: val_accuracy did not improve from 0.80588
# 783/783 [==============================] - 199s 254ms/step - loss: 0.3400 - accuracy: 0.8742 - val_loss: 0.5919 - val_accuracy: 0.8015
# Epoch 21/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.8805
# Epoch 00021: val_accuracy improved from 0.80588 to 0.80869, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 196s 251ms/step - loss: 0.3213 - accuracy: 0.8805 - val_loss: 0.5894 - val_accuracy: 0.8087
# Epoch 22/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8843
# Epoch 00022: val_accuracy improved from 0.80869 to 0.80963, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 192s 245ms/step - loss: 0.3159 - accuracy: 0.8843 - val_loss: 0.5889 - val_accuracy: 0.8096
# Epoch 23/100
# 783/783 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8868
# Epoch 00023: val_accuracy did not improve from 0.80963
# 783/783 [==============================] - 200s 256ms/step - loss: 0.3079 - accuracy: 0.8868 - val_loss: 0.5979 - val_accuracy: 0.8046
# Epoch 24/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8920
# Epoch 00024: val_accuracy improved from 0.80963 to 0.81025, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 194s 247ms/step - loss: 0.2937 - accuracy: 0.8920 - val_loss: 0.6064 - val_accuracy: 0.8103
# Epoch 25/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.8948
# Epoch 00025: val_accuracy did not improve from 0.81025
# 783/783 [==============================] - 193s 247ms/step - loss: 0.2872 - accuracy: 0.8948 - val_loss: 0.6012 - val_accuracy: 0.8081
# Epoch 26/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.8984
# Epoch 00026: val_accuracy improved from 0.81025 to 0.81307, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 193s 247ms/step - loss: 0.2759 - accuracy: 0.8984 - val_loss: 0.6077 - val_accuracy: 0.8131
# Epoch 27/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.9029
# Epoch 00027: val_accuracy improved from 0.81307 to 0.81400, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 193s 247ms/step - loss: 0.2720 - accuracy: 0.9029 - val_loss: 0.6116 - val_accuracy: 0.8140
# Epoch 28/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.9015
# Epoch 00028: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 194s 248ms/step - loss: 0.2678 - accuracy: 0.9015 - val_loss: 0.6309 - val_accuracy: 0.8087
# Epoch 29/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9084
# Epoch 00029: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 193s 247ms/step - loss: 0.2528 - accuracy: 0.9084 - val_loss: 0.6193 - val_accuracy: 0.8084
# Epoch 30/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.9115
# Epoch 00030: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 195s 249ms/step - loss: 0.2446 - accuracy: 0.9115 - val_loss: 0.6301 - val_accuracy: 0.8087
# Epoch 31/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9107
# Epoch 00031: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 203s 260ms/step - loss: 0.2482 - accuracy: 0.9107 - val_loss: 0.6350 - val_accuracy: 0.8103
# Epoch 32/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9123
# Epoch 00032: val_accuracy did not improve from 0.81400
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 783/783 [==============================] - 226s 288ms/step - loss: 0.2394 - accuracy: 0.9123 - val_loss: 0.6409 - val_accuracy: 0.8018
# Epoch 33/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2234 - accuracy: 0.9168
# Epoch 00033: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 197s 252ms/step - loss: 0.2234 - accuracy: 0.9168 - val_loss: 0.6329 - val_accuracy: 0.8131
# Epoch 34/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9204
# Epoch 00034: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 197s 251ms/step - loss: 0.2198 - accuracy: 0.9204 - val_loss: 0.6279 - val_accuracy: 0.8128
# Epoch 35/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9245
# Epoch 00035: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 205s 261ms/step - loss: 0.2081 - accuracy: 0.9245 - val_loss: 0.6398 - val_accuracy: 0.8093
# Epoch 36/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9226
# Epoch 00036: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 200s 255ms/step - loss: 0.2104 - accuracy: 0.9226 - val_loss: 0.6353 - val_accuracy: 0.8124
# Epoch 37/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9288
# Epoch 00037: val_accuracy did not improve from 0.81400
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 783/783 [==============================] - 199s 254ms/step - loss: 0.1998 - accuracy: 0.9288 - val_loss: 0.6491 - val_accuracy: 0.8093
# Epoch 38/100
# 783/783 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9269
# Epoch 00038: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 200s 256ms/step - loss: 0.2016 - accuracy: 0.9269 - val_loss: 0.6460 - val_accuracy: 0.8115
# Epoch 39/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9297
# Epoch 00039: val_accuracy did not improve from 0.81400
# 783/783 [==============================] - 199s 254ms/step - loss: 0.1943 - accuracy: 0.9297 - val_loss: 0.6403 - val_accuracy: 0.8121
# Epoch 40/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9284
# Epoch 00040: val_accuracy improved from 0.81400 to 0.81651, saving model to /Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5
# 783/783 [==============================] - 201s 257ms/step - loss: 0.1926 - accuracy: 0.9284 - val_loss: 0.6441 - val_accuracy: 0.8165
# Epoch 41/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9312
# Epoch 00041: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 204s 260ms/step - loss: 0.1911 - accuracy: 0.9312 - val_loss: 0.6547 - val_accuracy: 0.8140
# Epoch 42/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9313
# Epoch 00042: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 200s 256ms/step - loss: 0.1890 - accuracy: 0.9313 - val_loss: 0.6529 - val_accuracy: 0.8128
# Epoch 43/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9317
# Epoch 00043: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 201s 257ms/step - loss: 0.1856 - accuracy: 0.9317 - val_loss: 0.6506 - val_accuracy: 0.8153
# Epoch 44/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9316
# Epoch 00044: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 203s 260ms/step - loss: 0.1873 - accuracy: 0.9316 - val_loss: 0.6543 - val_accuracy: 0.8149
# Epoch 45/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9333
# Epoch 00045: val_accuracy did not improve from 0.81651
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 783/783 [==============================] - 203s 260ms/step - loss: 0.1832 - accuracy: 0.9333 - val_loss: 0.6519 - val_accuracy: 0.8134
# Epoch 46/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9330
# Epoch 00046: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 201s 257ms/step - loss: 0.1821 - accuracy: 0.9330 - val_loss: 0.6532 - val_accuracy: 0.8140
# Epoch 47/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9361
# Epoch 00047: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 202s 258ms/step - loss: 0.1771 - accuracy: 0.9361 - val_loss: 0.6532 - val_accuracy: 0.8124
# Epoch 48/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9362
# Epoch 00048: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 202s 258ms/step - loss: 0.1775 - accuracy: 0.9362 - val_loss: 0.6526 - val_accuracy: 0.8146
# Epoch 49/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9342
# Epoch 00049: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 204s 260ms/step - loss: 0.1785 - accuracy: 0.9342 - val_loss: 0.6511 - val_accuracy: 0.8156
# Epoch 50/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9361
# Epoch 00050: val_accuracy did not improve from 0.81651
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 783/783 [==============================] - 206s 263ms/step - loss: 0.1768 - accuracy: 0.9361 - val_loss: 0.6551 - val_accuracy: 0.8149
# Epoch 51/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9393
# Epoch 00051: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 204s 260ms/step - loss: 0.1674 - accuracy: 0.9393 - val_loss: 0.6621 - val_accuracy: 0.8140
# Epoch 52/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9355
# Epoch 00052: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 201s 257ms/step - loss: 0.1739 - accuracy: 0.9355 - val_loss: 0.6596 - val_accuracy: 0.8159
# Epoch 53/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9374
# Epoch 00053: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 201s 257ms/step - loss: 0.1751 - accuracy: 0.9374 - val_loss: 0.6571 - val_accuracy: 0.8153
# Epoch 54/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9398
# Epoch 00054: val_accuracy did not improve from 0.81651
# 783/783 [==============================] - 199s 254ms/step - loss: 0.1676 - accuracy: 0.9398 - val_loss: 0.6580 - val_accuracy: 0.8140
# Epoch 55/100
# 783/783 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9372
# Epoch 00055: val_accuracy did not improve from 0.81651
# Restoring model weights from the end of the best epoch.
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 783/783 [==============================] - 201s 256ms/step - loss: 0.1710 - accuracy: 0.9372 - val_loss: 0.6599 - val_accuracy: 0.8153
# Epoch 00055: early stopping

# %% [markdown]
# ### Plot the learning curves

# %%
# Clear the values of previous plot
# %matplotlib inline

fig = plt.figure(figsize=(15, 7))

# Plot training & validation accuracy values
fig.add_subplot(121)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/Acc_8.png')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/Acc_8.eps', format='eps', dpi=1000)

# Plot training & validation loss values
fig.add_subplot(122)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/Loss_8.png')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/Loss_8.eps', format='eps', dpi=1000)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Load the weights with which the model managed to achieve the highest validation accuracy

# %%
model.load_weights('/Users/gengyunxin/Documents/研究生/ICALT/checkpoint/ferplus_8.hdf5')

# %% [markdown]
# ### Pick randomly some images that the model hasn't seen yet and let it predict. The barplot on the write shows the confidence of its prediction

# %%
samples = np.random.choice(len(X_test), 5)

predictions = model.predict(X_test[samples], verbose=0)

fig, axes = plt.subplots(len(samples), 2, figsize=(18, 13))
fig.subplots_adjust(hspace=0.3, wspace=-0.2)

for i, (prediction, image, label) in enumerate(zip(predictions, X_test[samples], y_test[samples])):

    axes[i, 0].imshow(np.squeeze(image/255.))
    axes[i, 0].get_xaxis().set_visible(False)
    axes[i, 0].get_yaxis().set_visible(False)
    axes[i, 0].text(1., -3, f'Actual Emotion: [{mapping[np.argmax(label)]}]', weight='bold')

    axes[i, 1].bar(np.arange(len(prediction)), prediction, color=tl_hex)
    axes[i, 1].set_xticks(np.arange(len(prediction)))
    axes[i, 1].set_title(f"Model's Prediction: [{mapping[np.argmax(prediction)]}]", weight='bold')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/test.png')
plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/test.eps', format='eps', dpi=1000)

# %%
def show_confusion_matrix(X_test, y_test):
    """
    Show the confusion matrix of the unseen data.
  
    This function takes a fraction of the dataset that has not seen yet and
    tries to categorize each image into one of the 6 classes. The results are
    represented through a confusion matrix.

    Args:
        X_test (numpy.ndarray): unseen images
        y_test (numpy.ndarray): their corresponding labels
   
    Returns:
        No value
    """

    # Predict the test set (the system hasn't seen it yet)
    predictions = model.predict(X_test, verbose=0)
    
    y_classes =  np.argmax(predictions, axis=1)
    actual_classes =  np.argmax(y_test, axis=1)

    pred_labels = [mapping[element] for element in y_classes]
    actual_labels = [mapping[element] for element in actual_classes]

    # Create a dictionary
    data = {'y_Actual':    actual_labels,
            'y_Predicted': pred_labels}

    # Create a dataframe
    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

    # Calculate model's accuracy
    correct_predictions = sum(map(lambda x, y: x == y, pred_labels, actual_labels))
    all_samples = len(y_test)
    print(f"Final accuracy: {correct_predictions/all_samples * 100:.2f}%")

    # Plot the confusion matrix
    _, ax = plt.subplots(figsize=(10,8)) 
    sn.heatmap(confusion_matrix, annot = True, ax=ax)
    plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/confusion_matrix.png')
    plt.savefig('/Users/gengyunxin/Documents/研究生/ICALT/result/confusion_matrix.eps', format='eps', dpi=1000)
    plt.show()

# %%
show_confusion_matrix(X_test, y_test)
# Out:
# Final accuracy: 81.54%
